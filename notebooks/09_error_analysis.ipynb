# %%
import json
import numpy as np
from collections import defaultdict
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics.pairwise import cosine_similarity
import re
import string
from tqdm.auto import tqdm
from corefeval import get_metrics
from difflib import SequenceMatcher
try:
    from sentence_transformers import SentenceTransformer
    HAS_SENTENCE_TRANSFORMERS = True
except ImportError:
    HAS_SENTENCE_TRANSFORMERS = False
    print("Warning: Install sentence-transformers: pip install sentence-transformers")

# %%
# Load the original training labels
with open("../data/SOMD 2026/subtask 1/train_labels.json", "r") as f:
    train_labels = json.load(f)

# Select which file we should be working on
file_to_load = f"../../SOMD-2026/data/SOMD 2026/subtask 1/train_data.jsonl"
with open(file_to_load, 'r') as f:
    train_data = [json.loads(l) for l in list(f)]

# %%
class MentionDocumentEmbedding:
    """
    Cluster software mentions by embedding mention + document context.
    
    The key insight: mentions referring to the same software should appear
    in similar document contexts (similar research domains, methodologies, etc.)
    """
    
    def __init__(self, mentions_data, embedding_model='all-MiniLM-L6-v2'):
        """
        Args:
            mentions_data: List of mention dictionaries with keys:
                          mention, mention_id, start, end, type, docid, 
                          relations, sentence
            embedding_model: Sentence transformer model name
        """
        if not HAS_SENTENCE_TRANSFORMERS:
            raise ImportError("Install: pip install sentence-transformers")
        
        self.mentions = mentions_data
        self.mention_dict = {m['mention_id']: m for m in mentions_data}
        
        # Group mentions by document
        self.doc_mentions = defaultdict(list)
        for m in mentions_data:
            self.doc_mentions[m['docid']].append(m)
        
        print(f"Loading embedding model: {embedding_model}...")
        self.model = SentenceTransformer(embedding_model)
        print(f"Model loaded! Processing {len(mentions_data)} mentions from {len(self.doc_mentions)} documents")
        
        self.embeddings_cache = {}
    
    def normalize_mention(self, mention_text):
        """Normalize mention text."""
        text = mention_text.lower()
        text = re.sub(r'\s*v\.?\s*\d+[\w\.-]*', '', text)
        text = text.translate(str.maketrans('', '', string.punctuation))
        text = ' '.join(text.split())
        return text
    
    def get_embedding(self, text):
        """Get embedding with caching."""
        if text in self.embeddings_cache:
            return self.embeddings_cache[text]
        
        embedding = self.model.encode(text, convert_to_numpy=True)
        self.embeddings_cache[text] = embedding
        return embedding
    
    def build_document_context(self, docid, max_sentences=10):
        """
        Build document context by aggregating sentences from that document.
        
        Args:
            docid: Document ID
            max_sentences: Maximum sentences to include (for efficiency)
        
        Returns:
            String representing document context
        """
        doc_mentions = self.doc_mentions[docid]
        
        # Collect unique sentences from this document
        sentences = []
        seen_sentences = set()
        
        for mention in doc_mentions:
            sent = mention['sentence']
            if sent not in seen_sentences:
                sentences.append(sent)
                seen_sentences.add(sent)
                if len(sentences) >= max_sentences:
                    break
        
        # Combine sentences as document context
        doc_context = ' '.join(sentences)
        return doc_context
    
    def mention_plus_document_clustering(self, 
                                        distance_threshold=0.4,
                                        mention_weight=0.5,
                                        document_weight=0.5,
                                        linkage='average'):
        """
        Method 1: Embed "mention + full document context" together.
        
        Creates a combined representation by concatenating mention with
        document context, then embedding the whole thing.
        
        Args:
            distance_threshold: Clustering threshold (lower = more clusters)
            mention_weight: Weight for mention in combined text
            document_weight: Weight for document context
            linkage: 'average', 'complete', or 'single'
        """
        print("Building mention + document representations...")
        combined_texts = []
        
        for mention_obj in self.mentions:
            mention_text = self.normalize_mention(mention_obj['mention'])
            doc_context = self.build_document_context(mention_obj['docid'])
            
            # Create weighted combination
            # Repeat mention text to give it more weight
            mention_repeated = ' '.join([mention_text] * int(mention_weight * 10))
            doc_sampled = doc_context[:int(document_weight * 1000)]  # Limit doc length
            
            combined_text = f"{mention_repeated} {doc_sampled}"
            combined_texts.append(combined_text)
        
        print("Encoding combined representations...")
        embeddings = np.array([self.get_embedding(text) for text in combined_texts])
        
        print("Clustering...")
        clustering = AgglomerativeClustering(
            n_clusters=None,
            distance_threshold=distance_threshold,
            linkage=linkage,
            metric='cosine'
        )
        labels = clustering.fit_predict(embeddings)
        
        return self._labels_to_clusters(labels)
    
    def separate_embedding_clustering(self,
                                     distance_threshold=0.4,
                                     mention_weight=0.6,
                                     document_weight=0.4,
                                     linkage='average'):
        """
        Method 2: Embed mention and document separately, then combine.
        
        This gives you more control over the contribution of each component.
        
        Args:
            distance_threshold: Clustering threshold
            mention_weight: Weight for mention embedding (0-1)
            document_weight: Weight for document embedding (0-1)
            linkage: Linkage method
        """
        print("Encoding mentions...")
        mention_texts = [self.normalize_mention(m['mention']) for m in self.mentions]
        mention_embeddings = np.array([self.get_embedding(text) for text in mention_texts])
        
        print("Encoding document contexts...")
        doc_embeddings = []
        for mention_obj in self.mentions:
            doc_context = self.build_document_context(mention_obj['docid'])
            doc_emb = self.get_embedding(doc_context)
            doc_embeddings.append(doc_emb)
        doc_embeddings = np.array(doc_embeddings)
        
        # Normalize embeddings
        mention_embeddings = mention_embeddings / np.linalg.norm(mention_embeddings, axis=1, keepdims=True)
        doc_embeddings = doc_embeddings / np.linalg.norm(doc_embeddings, axis=1, keepdims=True)
        
        # Combine with weights
        print("Combining embeddings...")
        combined_embeddings = (mention_weight * mention_embeddings + 
                              document_weight * doc_embeddings)
        
        print("Clustering...")
        clustering = AgglomerativeClustering(
            n_clusters=None,
            distance_threshold=distance_threshold,
            linkage=linkage,
            metric='cosine'
        )
        labels = clustering.fit_predict(combined_embeddings)
        
        return self._labels_to_clusters(labels)
    
    def mention_sentence_document_clustering(self,
                                            distance_threshold=0.4,
                                            mention_weight=0.4,
                                            sentence_weight=0.3,
                                            document_weight=0.3,
                                            linkage='average'):
        """
        Method 3: Three-level embedding - mention + sentence + document.
        
        Most granular approach:
        - Mention: The software name itself
        - Sentence: Immediate context where mention appears
        - Document: Broader document context
        
        Args:
            distance_threshold: Clustering threshold
            mention_weight: Weight for mention embedding
            sentence_weight: Weight for sentence embedding
            document_weight: Weight for document embedding
            linkage: Linkage method
        """
        print("Encoding mentions...")
        mention_texts = [self.normalize_mention(m['mention']) for m in self.mentions]
        mention_embeddings = np.array([self.get_embedding(text) for text in mention_texts])
        
        print("Encoding sentences...")
        sentences = [m['sentence'] for m in self.mentions]
        sentence_embeddings = np.array([self.get_embedding(sent) for sent in sentences])
        
        print("Encoding documents...")
        doc_embeddings = []
        for mention_obj in self.mentions:
            doc_context = self.build_document_context(mention_obj['docid'])
            doc_emb = self.get_embedding(doc_context)
            doc_embeddings.append(doc_emb)
        doc_embeddings = np.array(doc_embeddings)
        
        # Normalize all embeddings
        mention_embeddings = mention_embeddings / np.linalg.norm(mention_embeddings, axis=1, keepdims=True)
        sentence_embeddings = sentence_embeddings / np.linalg.norm(sentence_embeddings, axis=1, keepdims=True)
        doc_embeddings = doc_embeddings / np.linalg.norm(doc_embeddings, axis=1, keepdims=True)
        
        # Combine with weights
        print("Combining three-level embeddings...")
        combined_embeddings = (mention_weight * mention_embeddings + 
                              sentence_weight * sentence_embeddings +
                              document_weight * doc_embeddings)
        
        print("Clustering...")
        clustering = AgglomerativeClustering(
            n_clusters=None,
            distance_threshold=distance_threshold,
            linkage=linkage,
            metric='cosine'
        )
        labels = clustering.fit_predict(combined_embeddings)
        
        return self._labels_to_clusters(labels)
    
    def two_stage_with_document_context(self,
                                       string_threshold=0.85,
                                       embedding_threshold=0.6,
                                       mention_weight=0.5,
                                       document_weight=0.5):
        """
        Method 4: Two-stage approach (your winning baseline + document context).
        
        Stage 1: Group by normalized mention string
        Stage 2: Merge clusters using mention+document embeddings
        
        This combines the speed of your baseline with document-aware semantics.
        """
        print("Stage 1: String-based grouping...")
        initial_clusters = defaultdict(list)
        for mention_obj in self.mentions:
            key = self.normalize_mention(mention_obj['mention'])
            initial_clusters[key].append(mention_obj['mention_id'])
        
        cluster_keys = list(initial_clusters.keys())
        print(f"Initial clusters: {len(cluster_keys)}")
        
        print("Stage 2: Computing cluster embeddings...")
        cluster_data = []
        
        for key in cluster_keys:
            mention_ids = initial_clusters[key]
            
            # Get mention embedding
            mention_emb = self.get_embedding(key)
            
            # Get average document context embedding for this cluster
            doc_embeddings = []
            for mid in mention_ids[:5]:  # Sample up to 5 for efficiency
                doc_context = self.build_document_context(self.mention_dict[mid]['docid'])
                doc_embeddings.append(self.get_embedding(doc_context))
            
            avg_doc_emb = np.mean(doc_embeddings, axis=0)
            
            cluster_data.append({
                'key': key,
                'mention_ids': mention_ids,
                'mention_emb': mention_emb,
                'doc_emb': avg_doc_emb
            })
        
        # Normalize and combine embeddings
        print("Combining embeddings...")
        combined_embeddings = []
        for cluster in cluster_data:
            mention_emb = cluster['mention_emb'] / np.linalg.norm(cluster['mention_emb'])
            doc_emb = cluster['doc_emb'] / np.linalg.norm(cluster['doc_emb'])
            combined = mention_weight * mention_emb + document_weight * doc_emb
            combined_embeddings.append(combined)
        
        combined_embeddings = np.array(combined_embeddings)
        
        # Compute similarity and merge
        print("Computing similarities and merging...")
        similarity_matrix = cosine_similarity(combined_embeddings)
        
        cluster_mapping = {}
        final_clusters = []
        next_cluster_id = 0
        
        for i in range(len(cluster_data)):
            if i in cluster_mapping:
                continue
            
            cluster_mapping[i] = next_cluster_id
            merged_mentions = cluster_data[i]['mention_ids'].copy()
            
            for j in range(i + 1, len(cluster_data)):
                if j not in cluster_mapping:
                    if similarity_matrix[i, j] >= embedding_threshold:
                        cluster_mapping[j] = next_cluster_id
                        merged_mentions.extend(cluster_data[j]['mention_ids'])
            
            final_clusters.append(merged_mentions)
            next_cluster_id += 1
        
        print(f"Final clusters: {len(final_clusters)}")
        return final_clusters
    
    def _labels_to_clusters(self, labels):
        """Convert cluster labels to list of mention_id lists."""
        clusters_dict = defaultdict(list)
        for idx, label in enumerate(labels):
            mention_id = self.mentions[idx]['mention_id']
            clusters_dict[label].append(mention_id)
        return list(clusters_dict.values())
    
    def save_clusters(self, clusters, filename='clusters.json'):


        """Save clusters to JSON file."""
        with open(filename, 'w') as f:
            json.dump(clusters, f, indent=2)
        print(f"Saved {len(clusters)} clusters to {filename}")



class SoftwareCoreferenceBaseline:

    """ 
    Fuzzy String Match Baseline method for software mention coreference resolution.
    """

    def __init__(self, mentions_data):

        """
        mentions_data = test_data (data used for inference)
        """
        
        self.mentions = mentions_data


    def _string_similarity(self, s1, s2):
        
        """
        Calculate string similarity between two strings s1 and s2 using SequenceMatcher (we can use any other metrics, like the Levenshtein distance etc.)
        """
        
        return SequenceMatcher(None, s1, s2).ratio()
    
        
    def normalize_mention(self, mention_text, remove_version=True):
        
        """ 
        Function to perform some text processing on the mentions. 
        """
        
        # Lowercase
        text = mention_text.lower()
        
        # Remove software version numbers
        if remove_version:
            text = re.sub(r'\s*v\.?\s*\d+[\w\.-]*', '', text)
            text = re.sub(r'\s+\d+\.\d+[\w\.-]*$', '', text)
        
        # Remove punctuations
        text = text.translate(str.maketrans('', '', string.punctuation))
        
        # Remove extra whitespace
        text = ' '.join(text.split())
        
        return text
    
    def fuzzy_matching(self, threshold = 0.85, remove_version = True):
        """
        Fuzzy string matching with normalized mentions.
        
        Args: - threshold value : Similarity threshold (0-1). We set by defalut to 0.85 (we can use other values)
              - remove_version: Whether to remove version info before matching
        
        Returns clusters as list of lists of mention_ids.
        """
        
        
        # We first normalize all mentions
        normalized_mentions = []
        for mention_obj in self.mentions:
            norm_text = self.normalize_mention(mention_obj['mention'], remove_version)
            normalized_mentions.append({
                'mention_id': mention_obj['mention_id'],
                'normalized': norm_text,
                'original': mention_obj['mention']
            })
        
        # Build clusters
        clusters = []
        used = set()
        
        for i, mention1 in enumerate(normalized_mentions):
            if mention1['mention_id'] in used:
                continue
            
            # Start a new cluster
            cluster = [mention1['mention_id']]
            used.add(mention1['mention_id'])
            
            # Find similar mentions
            for j, mention2 in enumerate(normalized_mentions):

                if i != j and mention2['mention_id'] not in used:
                    similarity = self._string_similarity(mention1['normalized'], mention2['normalized'])
                    
                    # If the similarity is higher than the threshold value, let's add them in the same cluster
                    if similarity >= threshold:
                        cluster.append(mention2['mention_id'])
                        used.add(mention2['mention_id'])
            
            clusters.append(cluster)
        
        return clusters
    
    
    
    def predict(self, fuzzy_threshold = 0.85):
        
        """
        Function to predict clusters. There is a two-stage approach: First, an exact matching, then fuzzy matching.        

        """
        
        # Etape 1 : Exact matching on normalized mentions
        clusters_dict = defaultdict(list)
        
        for mention_obj in self.mentions:
            key = self.normalize_mention(mention_obj['mention'])
            clusters_dict[key].append(mention_obj['mention_id'])
        
        # Etape 2: Fuzzy matching between cluster representatives
        cluster_keys = list(clusters_dict.keys())
        cluster_mapping = {}  # Maps cluster key to final cluster id
        final_clusters = []
        next_cluster_id = 0
        
        for i, key1 in enumerate(cluster_keys):
            
            if key1 in cluster_mapping:
                continue
            
            # Start new cluster
            cluster_mapping[key1] = next_cluster_id
            merged_mentions = clusters_dict[key1].copy()
            
            # Find similar clusters
            for key2 in cluster_keys[i+1:]:
                if key2 not in cluster_mapping:
                    similarity = self._string_similarity(key1, key2)
                    if similarity >= fuzzy_threshold:
                        cluster_mapping[key2] = next_cluster_id
                        merged_mentions.extend(clusters_dict[key2])
            
            final_clusters.append(merged_mentions)
            next_cluster_id += 1
        
        return final_clusters

# %%
doc_embed = MentionDocumentEmbedding(
        train_data,
        embedding_model='all-MiniLM-L6-v2'  # Or try 'allenai/scibert_scivocab_uncased'
    )
    
c = doc_embed.separate_embedding_clustering(
                                                            distance_threshold=0.4,
                                                            mention_weight=0.6,
                                                            document_weight=0.4
                                                        )

emb_predicted_clusters = doc_embed.separate_embedding_clustering(
                                                                distance_threshold=0.4,
                                                                mention_weight=0.6,
                                                                document_weight=0.4
                                                            )
# Out:
# Loading embedding model: all-MiniLM-L6-v2...
# Model loaded! Processing 2974 mentions from 973 documents
# Encoding mentions...
# Encoding document contexts...
# Combining embeddings...
# Clustering...
# Encoding mentions...
# Encoding document contexts...
# Combining embeddings...
# Clustering...

# %%
len(emb_predicted_clusters)
# Out:
# 630

# %%
embedding_scores = get_metrics(emb_predicted_clusters, train_labels, verbose=False)
embedding_scores
# Out:
# (np.float64(0.8164054299254234),
#  {'muc': {'precision': 0.9377133105802048,
#    'recall': 0.9808121374386435,
#    'f1': 0.9587786259541985},
#   'b_cubed': {'precision': 0.877615352363792,
#    'recall': 0.9272259909669618,
#    'f1': 0.9017388345965095},
#   'ceafe': {'precision': np.float64(0.8953469658973737),
#    'recall': np.float64(0.43851236119666737),
#    'f1': np.float64(0.5886988292255626)},
#   'lea': {'precision': 0.8680848213516831,
#    'recall': 0.9222263341708049,
#    'f1': 0.8943369202331095}})

# %%
coref_resolver = SoftwareCoreferenceBaseline(train_data)
fuzzy_predicted_clusters = coref_resolver.predict(fuzzy_threshold = 0.83)

# %%
len(fuzzy_predicted_clusters)
# Out:
# 778

# %%
fuzzy_scores = get_metrics(fuzzy_predicted_clusters, train_labels, verbose=False)
fuzzy_scores
# Out:
# (np.float64(0.8293725711782812),
#  {'muc': {'precision': 0.9867941712204007,
#    'recall': 0.9669790272199911,
#    'f1': 0.9767861167455488},
#   'b_cubed': {'precision': 0.9689433629837898,
#    'recall': 0.8744433520933862,
#    'f1': 0.9192711170002232},
#   'ceafe': {'precision': np.float64(0.9142358405859741),
#    'recall': np.float64(0.4377855116584951),
#    'f1': np.float64(0.5920604797890717)},
#   'lea': {'precision': 0.9657542954362742,
#    'recall': 0.8696981982862774,
#    'f1': 0.9152127593612598}})

# %%
def mention_to_cluster_id(clusters):
    m2c = {}
    for cid, cl in enumerate(clusters):
        for m in cl:
            m2c[m] = cid
    return m2c

def best_gold_for_pred(pred_cl, gold_m2c):
    # count how many mentions in pred_cl belong to each gold cluster
    counts = defaultdict(int)
    for m in pred_cl:
        if m in gold_m2c:
            counts[gold_m2c[m]] += 1
    if not counts:
        return None, counts
    best = max(counts.items(), key=lambda x: x[1])[0]
    return best, counts

def mismatch_examples(pred_clusters, gold_clusters, max_examples=None, min_overlap=1):
    gold_m2c = mention_to_cluster_id(gold_clusters)
    pred_m2c = mention_to_cluster_id(pred_clusters)

    examples = []

    # --- Pred -> Gold mismatches (extras / missing)
    for i, pred_cl in enumerate(pred_clusters):
        pred_set = set(pred_cl)
        best_gid, counts = best_gold_for_pred(pred_set, gold_m2c)

        if best_gid is None:
            examples.append({
                "type": "spurious_pred_cluster",
                "pred_cluster_id": i,
                "pred_cluster": pred_cl,
                "gold_cluster_id": None,
                "gold_cluster": None,
                "extra": pred_cl,
                "missing": [],
                "overlap_counts": dict(counts),
            })
            continue

        overlap = counts[best_gid]
        if overlap < min_overlap:
            continue

        gold_set = set(gold_clusters[best_gid])
        extra = sorted(pred_set - gold_set)
        missing = sorted(gold_set - pred_set)

        # classify a bit
        touched_gold = [gid for gid, c in counts.items() if c > 0]
        if len(touched_gold) > 1:
            err_type = "merge_like"   # pred cluster mixes multiple gold clusters
        elif missing:
            err_type = "split_like"   # pred cluster is subset of its gold match
        else:
            err_type = "mismatch"

        if extra or missing or len(touched_gold) > 1:
            examples.append({
                "type": err_type,
                "pred_cluster_id": i,
                "pred_cluster": sorted(pred_set),
                "gold_cluster_id": best_gid,
                "gold_cluster": sorted(gold_set),
                "extra": extra,
                "missing": missing,
                "overlap_counts": dict(counts),  # shows merges clearly
            })

        if max_examples and len(examples) >= max_examples:
            return examples

    # --- Mention-level misses: mentions in gold but never predicted (optional but useful)
    # This catches "dropped mentions" that don't appear in any pred cluster.
    gold_mentions = set(m for cl in gold_clusters for m in cl)
    pred_mentions = set(m for cl in pred_clusters for m in cl)
    dropped = sorted(gold_mentions - pred_mentions)
    if dropped:
        examples.append({
            "type": "gold_mentions_missing_globally",
            "mentions": dropped
        })

    # Also: predicted mentions not in gold at all
    hallucinated = sorted(pred_mentions - gold_mentions)
    if hallucinated:
        examples.append({
            "type": "pred_mentions_not_in_gold",
            "mentions": hallucinated
        })

    return examples

# %%
fuzzy_mismatch_examples = mismatch_examples(fuzzy_predicted_clusters, train_labels, max_examples = 15000)
embedding_mismatch_examples = mismatch_examples(emb_predicted_clusters, train_labels, max_examples = 15000)

# %%
for ex in fuzzy_mismatch_examples:

    pred_cluster = ex["pred_cluster"]
    gold_cluster = ex["gold_cluster"]
    extra = ex["extra"]
    missing = ex["missing"]


    ex["pred_mentions"] = []
    ex["gold_mentions"] = []
    ex["extra_mentions"] = []
    ex["missing_mentions"] = []

    for m_id in pred_cluster:
        for d in train_data:
            if d["mention_id"] == m_id:
                mention = d["mention"]
                ex["pred_mentions"].append(mention)

    for m_id in gold_cluster:
        for d in train_data:
            if d["mention_id"] == m_id:
                mention = d["mention"]
                ex["gold_mentions"].append(mention)

    for m_id in extra:
        for d in train_data:
            if d["mention_id"] == m_id:
                mention = d["mention"]
                ex["extra_mentions"].append(mention)

    for m_id in missing:
        for d in train_data:
            if d["mention_id"] == m_id:
                mention = d["mention"]
                ex["missing_mentions"].append(mention)


    assert len(pred_cluster) == len(ex["pred_mentions"])
    assert len(gold_cluster) == len(ex["gold_mentions"])
    assert len(extra) == len(ex["extra_mentions"])
    assert len(missing) == len(ex["missing_mentions"])

    

for ex in embedding_mismatch_examples:

    pred_cluster = ex["pred_cluster"]
    gold_cluster = ex["gold_cluster"]
    extra = ex["extra"]
    missing = ex["missing"]


    ex["pred_mentions"] = []
    ex["gold_mentions"] = []
    ex["extra_mentions"] = []
    ex["missing_mentions"] = []

    for m_id in pred_cluster:
        for d in train_data:
            if d["mention_id"] == m_id:
                mention = d["mention"]
                ex["pred_mentions"].append(mention)

    for m_id in gold_cluster:
        for d in train_data:
            if d["mention_id"] == m_id:
                mention = d["mention"]
                ex["gold_mentions"].append(mention)

    for m_id in extra:
        for d in train_data:
            if d["mention_id"] == m_id:
                mention = d["mention"]
                ex["extra_mentions"].append(mention)

    for m_id in missing:
        for d in train_data:
            if d["mention_id"] == m_id:
                mention = d["mention"]
                ex["missing_mentions"].append(mention)


    assert len(pred_cluster) == len(ex["pred_mentions"])
    assert len(gold_cluster) == len(ex["gold_mentions"])
    assert len(extra) == len(ex["extra_mentions"])
    assert len(missing) == len(ex["missing_mentions"])

# %%
for ex in embedding_mismatch_examples:
    print("\n---", ex["type"], "---")
    print("pred_cluster_id:", ex.get("pred_cluster_id"))
    print("gold_cluster_id:", ex.get("gold_cluster_id"))
    print("extra:", ex.get("extra_mentions"))
    print("missing:", ex.get("missing_mentions"))
# Out:
# --- split_like ---
# pred_cluster_id: 0
# gold_cluster_id: 0
# extra: []
# missing: ['MATLB']
#
# --- split_like ---
# pred_cluster_id: 2
# gold_cluster_id: 2
# extra: []
# missing: ['Statistical Package for Social Sciences', 'Statistical Package for Social Science', 'Statistical Package for Social Sciences', 'Statistical Package for the Social Sciences', 'Statistical Package for Social Sciences', 'Statistical Package for the Social Sciences', 'Statistical Program for the Social Sciences', 'Statistical Package for Social Sciences', 'Statistical Package for the Social Science', 'Software Package for Statistical Analysis', 'Statistical Package for the Social Sciences', 'Statistical Product and Service Solutions', 'Statistical Package for Social Sciences', 'Statistical Package for Social Sciences', 'Statistical Package for Social Sciences', 'Statistical Package for the Social Sciences', 'Statistical Package for the Social Sciences', 'Statistical Package for the Social Sciences', 'PASW Statistics', 'Statistical Package for the Social Sciences', 'Statistical Package for the Social Sciences', 'Statistical Package for Social Sciences', 'Statistical Package for Social Sciences', 'Statistical Package for the Social Sciences', 'PASW Statistics', 'Statistical Package for Social Sciences', 'Statistical Package for the Social Sciences', 'Statistical Package for the Social Science', 'PASW', 'Statistical Package for the Social Sciences', 'Statistical Package for the Social Sciences', 'Statistical Package for the Social Sciences', 'Statistical Package for Social Sciences', 'Statistical Package for Social Sciences', 'PASW Statistic', 'Statistical Package for the Social Sciences', 'PASW Statistic', 'Statistical Package for the Social Sciences', 'Statistical Package for Social Sciences', 'Statistical Package for Social Sciences', 'Statistical Package for the Social Sciences', 'Statistical Package for Social Sciences', 'Statistical package for Social Sciences', 'statistical package for social sciences', 'Statistical Package for Social Sciences', 'Statistical Package for the Social Sciences', 'PASW', 'Statistical Package for the Social Sciences', 'Statistical Package for the Social Sciences', 'statistical package for social science', 'Statistical Package for the Social Sciences', 'Statistical Package for the Social Sciences', 'Statistical Package for Social Sciences', 'Statistical Package for the Social Sciences', 'Statistical Package for Social Sciences', 'PASW Statistics', 'PASW Statistics', 'statistical package for social science']
#
# --- split_like ---
# pred_cluster_id: 3
# gold_cluster_id: 3
# extra: []
# missing: ['Statistical Analysis System', 'Statistical Analysis Systems', 'statistical analyses software', 'Statistical Analysis System', 'Statistical Analysis System', 'Statistical Analysis System']
#
# --- merge_like ---
# pred_cluster_id: 7
# gold_cluster_id: 7
# extra: ['BIOEDIT', 'Bioportal', 'BioEdit', 'BioEdit']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 9
# gold_cluster_id: 9
# extra: ['GENELAND', 'GENEMAPPER', 'GeneMapper', 'GENEPOP', 'GENEPOP', 'GENELAND', 'GENEPOP', 'GENEPOP', 'GENEPOP']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 16
# gold_cluster_id: 16
# extra: ['STATISTICA', 'Statistica', 'Statview', 'Statistica', 'StatView', 'Statview', 'Statistica', 'STATVIEW', 'Statistica', 'Statistica', 'Statistica', 'STATISTICA']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 19
# gold_cluster_id: 19
# extra: []
# missing: ['GNU R']
#
# --- merge_like ---
# pred_cluster_id: 21
# gold_cluster_id: 21
# extra: ['FMRIB’s Integrated Registration and Segmentation Tool', "FMRIB's ICA-based X-noiseifier", 'FMRIB’s Diffusion Toolbox', "FMRIB's Automated Segmentation Tool", 'FMRIB’s Diffusion Toolbox']
# missing: ['FSL', 'FSL', 'FSL', 'FSL', 'FSL', 'FSL', 'FSL', 'FSL', 'FSL', 'FSL', 'FSL', 'FSL', 'FSL', 'FSL']
#
# --- merge_like ---
# pred_cluster_id: 23
# gold_cluster_id: 25
# extra: ['FNIRT', 'FDT', 'FNIRT']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 24
# gold_cluster_id: 21
# extra: ['FSLView', 'FSL-VBM']
# missing: ['FMRIB Software Library', 'FMRIB Software Library']
#
# --- merge_like ---
# pred_cluster_id: 25
# gold_cluster_id: 32
# extra: ['Multivariate Exploratory Linear Optimized Decomposition into Independent Components']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 26
# gold_cluster_id: 269
# extra: ['tract-based spatial statistics']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 27
# gold_cluster_id: 27
# extra: []
# missing: ['Multivariate Exploratory Linear Optimized Decomposition into Independent Components']
#
# --- split_like ---
# pred_cluster_id: 28
# gold_cluster_id: 29
# extra: []
# missing: ['FSL-VBM']
#
# --- split_like ---
# pred_cluster_id: 29
# gold_cluster_id: 31
# extra: []
# missing: ['tract-based spatial statistics']
#
# --- split_like ---
# pred_cluster_id: 32
# gold_cluster_id: 35
# extra: []
# missing: ['IPA', 'IPA']
#
# --- merge_like ---
# pred_cluster_id: 33
# gold_cluster_id: 265
# extra: ['Genome browser', 'Santa Cruz genome browser', 'Genomics Suite']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 34
# gold_cluster_id: 36
# extra: []
# missing: ['Genomics Suite']
#
# --- split_like ---
# pred_cluster_id: 35
# gold_cluster_id: 37
# extra: []
# missing: ['GraphPad', 'GraphPad']
#
# --- merge_like ---
# pred_cluster_id: 36
# gold_cluster_id: 38
# extra: ['MACS']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 38
# gold_cluster_id: 40
# extra: ['MSOffice']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 42
# gold_cluster_id: 45
# extra: ['DIVA-GIS']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 43
# gold_cluster_id: 46
# extra: ['Java Advanced Imaging', 'FigureJ']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 44
# gold_cluster_id: 47
# extra: []
# missing: ['Win']
#
# --- merge_like ---
# pred_cluster_id: 45
# gold_cluster_id: 2
# extra: ['Statistical Analysis System', 'Statistical Analysis Systems', 'statistical analyses software', 'Statistical Analysis System', 'Statistical Analysis System', 'Statistical Analysis System']
# missing: ['SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Product and Service Solutions', 'SPSS Dimensions', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'PASW Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS Statistics', 'PASW Statistics', 'SPSS', 'SPSS Statistics', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS statistics', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'PASW', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS statistics', 'SPSS', 'SPSS', 'SPSS', 'PASW Statistic', 'SPSS', 'SPSS', 'PASW Statistic', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS statistics', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'PASW', 'SPSS', 'SPSS Statistics', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS statistics', 'PASW Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'PASW Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS Statistics', 'SPSS Statistics']
#
# --- merge_like ---
# pred_cluster_id: 47
# gold_cluster_id: 50
# extra: ['dcm4che']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 50
# gold_cluster_id: 54
# extra: ['C#', 'C#', 'C#', 'C#', 'C', 'C#', 'C', 'C#', 'C', 'C', 'C']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 54
# gold_cluster_id: 58
# extra: ['psych']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 59
# gold_cluster_id: 65
# extra: ['microRNA', 'microRNA', 'Mirdeep2', 'Mirdeep2']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 65
# gold_cluster_id: 70
# extra: ['Microscopy Image Browser']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 67
# gold_cluster_id: 73
# extra: ['rjags']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 77
# gold_cluster_id: 83
# extra: ['immunoSEQ Analyzer']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 78
# gold_cluster_id: 84
# extra: ['Rtsne']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 80
# gold_cluster_id: 255
# extra: ['DESeq2']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 83
# gold_cluster_id: 89
# extra: ['edge']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 90
# gold_cluster_id: 98
# extra: ['Java JRE', 'Java Runtime Environment', 'Java Virtual Machine', 'JDK']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 96
# gold_cluster_id: 105
# extra: ['BioTools', 'ProteomeWeaver']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 106
# gold_cluster_id: 117
# extra: ['SciPy', 'NumPy', 'SciPy', 'NumPy']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 109
# gold_cluster_id: 120
# extra: ['Rhtslib']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 111
# gold_cluster_id: 123
# extra: ['MSAProbs']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 114
# gold_cluster_id: 128
# extra: ['ENSEMBLE']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 119
# gold_cluster_id: 301
# extra: ['PhyML', 'PyMOL', 'PhyML']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 124
# gold_cluster_id: 140
# extra: ['WinBugs']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 125
# gold_cluster_id: 141
# extra: ['runmlwin', 'runmlwin']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 127
# gold_cluster_id: 144
# extra: ['EyeLink API', 'EyeVision', 'EyeVision', 'Eyelink Toolbox']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 129
# gold_cluster_id: 146
# extra: []
# missing: ['ANFI']
#
# --- merge_like ---
# pred_cluster_id: 130
# gold_cluster_id: 147
# extra: ['3dttest+ +', '3dDetrend', '3dFWHMx', '3dmaskave', '3dDeconvolve', '3dDespike', '3dmaskave', '3dClustsim', '3dttest+ +']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 136
# gold_cluster_id: 154
# extra: ['OpenCL']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 140
# gold_cluster_id: 2
# extra: []
# missing: ['SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'Statistical Package for Social Science', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'Statistical Program for the Social Sciences', 'SPSS', 'Statistical Package for Social Sciences', 'Statistical Package for the Social Science', 'SPSS', 'SPSS', 'SPSS', 'Software Package for Statistical Analysis', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Product and Service Solutions', 'SPSS Dimensions', 'Statistical Package for Social Sciences', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'Statistical Package for Social Sciences', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS Statistics', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS Statistics', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS Statistics', 'SPSS', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS Statistics', 'SPSS Statistics', 'SPSS', 'SPSS Statistics', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS Statistics', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'Statistical Package for the Social Science', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS statistics', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'Statistical Package for the Social Sciences', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'Statistical Package for Social Sciences', 'Statistical Package for Social Sciences', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS statistics', 'Statistical package for Social Sciences', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'statistical package for social sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS Statistics', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS  ...
#
# --- merge_like ---
# pred_cluster_id: 149
# gold_cluster_id: 167
# extra: ['ArcMap', 'ArcView', 'ArcView', 'ArcView']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 159
# gold_cluster_id: 178
# extra: ['Expression Analysis Systematic Explorer', 'Database for Annotation, Visualization and Integrated Discovery']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 160
# gold_cluster_id: 177
# extra: []
# missing: ['Database for Annotation, Visualization and Integrated Discovery']
#
# --- merge_like ---
# pred_cluster_id: 165
# gold_cluster_id: 184
# extra: ['ltm']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 167
# gold_cluster_id: 187
# extra: ['SLINK']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 168
# gold_cluster_id: 35
# extra: []
# missing: ['Ingenuity Pathway Analysis', 'Ingenuity Pathway Analysis', 'Ingenuity', 'Ingenuity Pathway Analysis', 'Ingenuity']
#
# --- split_like ---
# pred_cluster_id: 169
# gold_cluster_id: 188
# extra: []
# missing: ['WPS', 'WPS']
#
# --- split_like ---
# pred_cluster_id: 170
# gold_cluster_id: 188
# extra: []
# missing: ['WholePathwayScope', 'WholePathwayScope', 'WholePathwayScope']
#
# --- split_like ---
# pred_cluster_id: 177
# gold_cluster_id: 195
# extra: []
# missing: ['Analysis of Moment Structures']
#
# --- split_like ---
# pred_cluster_id: 179
# gold_cluster_id: 197
# extra: []
# missing: ['SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM', 'SPM']
#
# --- split_like ---
# pred_cluster_id: 180
# gold_cluster_id: 197
# extra: []
# missing: ['statistical parametric mapping', 'Statistical Parametric Mapping', 'Statistical Parametric Mapping', 'statistical parametric mapping']
#
# --- merge_like ---
# pred_cluster_id: 185
# gold_cluster_id: 202
# extra: ['raster', 'rgdal']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 187
# gold_cluster_id: 206
# extra: ['Cogent']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 190
# gold_cluster_id: 210
# extra: []
# missing: ['g++']
#
# --- merge_like ---
# pred_cluster_id: 191
# gold_cluster_id: 211
# extra: ['Unix', 'Unix', 'Ubuntu']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 198
# gold_cluster_id: 218
# extra: []
# missing: ['CANTAB']
#
# --- split_like ---
# pred_cluster_id: 200
# gold_cluster_id: 218
# extra: []
# missing: ['Cambridge Neuropsychological Test Automated Battery']
#
# --- merge_like ---
# pred_cluster_id: 201
# gold_cluster_id: 220
# extra: ['cellXpress', 'cellXpress', 'cellXpress', 'cellXpress', 'cellXpress', 'cellXpress', 'cellXpress']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 204
# gold_cluster_id: 652
# extra: ['Brain Vision Analyzer', 'Brain Vision Recorder', 'Brain Vision Analyzer']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 210
# gold_cluster_id: 540
# extra: ['NeuroQuant']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 214
# gold_cluster_id: 233
# extra: ['WinEEG']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 217
# gold_cluster_id: 236
# extra: ['plotrix']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 218
# gold_cluster_id: 237
# extra: ['gdata']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 219
# gold_cluster_id: 239
# extra: ['hgu95av2']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 223
# gold_cluster_id: 246
# extra: ["Hawth's analysis tools for ArcGis"]
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 231
# gold_cluster_id: 254
# extra: ['GOseq']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 236
# gold_cluster_id: 395
# extra: ['Comprehensive Meta-Analysis', 'Comprehensive Meta-Analysis']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 249
# gold_cluster_id: 281
# extra: ['Epi']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 252
# gold_cluster_id: 284
# extra: ['Genome Analysis Toolkit', 'Prokaryotic Genomes Automatic Annotation Pipeline']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 254
# gold_cluster_id: 287
# extra: ['SPAGeDI']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 263
# gold_cluster_id: 296
# extra: []
# missing: ['CBFA', 'CBFA', 'CBFA', 'CBFA', 'CBFA']
#
# --- split_like ---
# pred_cluster_id: 264
# gold_cluster_id: 296
# extra: []
# missing: ['Constraint-based Flux Analysis']
#
# --- merge_like ---
# pred_cluster_id: 266
# gold_cluster_id: 210
# extra: ['GLPK']
# missing: ['gcc']
#
# --- merge_like ---
# pred_cluster_id: 267
# gold_cluster_id: 303
# extra: ['Netcdf', 'Pycluster']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 268
# gold_cluster_id: 305
# extra: ['tk']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 274
# gold_cluster_id: 312
# extra: ['Illustrator']
# missing: ['MSOffice']
#
# --- merge_like ---
# pred_cluster_id: 276
# gold_cluster_id: 315
# extra: ['ENMtools', 'ENMtools']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 277
# gold_cluster_id: 317
# extra: []
# missing: ['Leica Application Suite Advanced Fluorescence']
#
# --- split_like ---
# pred_cluster_id: 278
# gold_cluster_id: 317
# extra: []
# missing: ['LAS AF']
#
# --- merge_like ---
# pred_cluster_id: 287
# gold_cluster_id: 336
# extra: ['Sift']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 288
# gold_cluster_id: 337
# extra: ['PolyPhred']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 290
# gold_cluster_id: 340
# extra: []
# missing: ['Combined Annotation Dependent Depletion']
#
# --- split_like ---
# pred_cluster_id: 291
# gold_cluster_id: 341
# extra: []
# missing: ['ART', 'ART']
#
# --- split_like ---
# pred_cluster_id: 293
# gold_cluster_id: 341
# extra: []
# missing: ['Artifact Rejection Toolbox']
#
# --- split_like ---
# pred_cluster_id: 294
# gold_cluster_id: 343
# extra: []
# missing: ['WFU-Pickatlas', 'WFU-Pickatlas', 'WFU-Pickatlas', 'WFU-Pickatlas', 'WFU pickatlas', 'WFU-pick atlas']
#
# --- merge_like ---
# pred_cluster_id: 297
# gold_cluster_id: 346
# extra: ['Experiment Builder']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 301
# gold_cluster_id: 350
# extra: []
# missing: ['Prediction of Activity Spectra for Substances']
#
# --- split_like ---
# pred_cluster_id: 302
# gold_cluster_id: 350
# extra: []
# missing: ['PASS']
#
# --- merge_like ---
# pred_cluster_id: 311
# gold_cluster_id: 360
# extra: ['Visual Studio']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 316
# gold_cluster_id: 365
# extra: ['Pixelmator']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 322
# gold_cluster_id: 372
# extra: []
# missing: ['NIS-Elements', 'NIS-Elements']
#
# --- merge_like ---
# pred_cluster_id: 327
# gold_cluster_id: 377
# extra: ['ProctorU']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 328
# gold_cluster_id: 379
# extra: ['Mach2QTL']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 332
# gold_cluster_id: 383
# extra: ['Genevestigator']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 334
# gold_cluster_id: 372
# extra: []
# missing: ['NIS', 'NIS']
#
# --- merge_like ---
# pred_cluster_id: 339
# gold_cluster_id: 389
# extra: ['Techila Technologies']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 344
# gold_cluster_id: 37
# extra: []
# missing: ['Prism', 'Prism', 'Prism', 'PRISM', 'Prism', 'prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism', 'Prism']
#
# --- split_like ---
# pred_cluster_id: 347
# gold_cluster_id: 343
# extra: []
# missing: ['Wake Forest University PickAtlas']
#
# --- merge_like ---
# pred_cluster_id: 348
# gold_cluster_id: 399
# extra: ['LI-toolbox']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 360
# gold_cluster_id: 727
# extra: ['CLUMPP']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 361
# gold_cluster_id: 416
# extra: ['DIYABC']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 365
# gold_cluster_id: 422
# extra: []
# missing: ['HRC']
#
# --- merge_like ---
# pred_cluster_id: 366
# gold_cluster_id: 424
# extra: ['HRC']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 371
# gold_cluster_id: 570
# extra: ['SNPTEST', 'NovoSNP', 'SNPTEST', 'SNPTEST', 'SNPTEST']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 385
# gold_cluster_id: 442
# extra: ['R/Qtl', 'qxpak']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 389
# gold_cluster_id: 448
# extra: ['jQuery']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 392
# gold_cluster_id: 451
# extra: []
# missing: ['Diffeomorphic Anatomical Registration Through Exponentiated Lie Algebra']
#
# --- merge_like ---
# pred_cluster_id: 395
# gold_cluster_id: 454
# extra: ['Image Acquisition Toolbox']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 399
# gold_cluster_id: 459
# extra: ['HTML', 'Safari', 'Chrome']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 408
# gold_cluster_id: 472
# extra: []
# missing: ['Cancer, Heart And Soft Tissue Environment']
#
# --- split_like ---
# pred_cluster_id: 409
# gold_cluster_id: 472
# extra: []
# missing: ['Chaste', 'Chaste', 'Chaste', 'Chaste', 'Chaste', 'Chaste', 'Chaste', 'Chaste']
#
# --- split_like ---
# pred_cluster_id: 410
# gold_cluster_id: 473
# extra: []
# missing: ['PEPIS', 'PEPIS', 'PEPIS', 'PEPIS']
#
# --- merge_like ---
# pred_cluster_id: 411
# gold_cluster_id: 473
# extra: ['Pep2Path', 'Pep2Path', 'Pep2Path', 'Pep2Path']
# missing: ['Pipeline for estimating EPIStatic genetic effects']
#
# --- merge_like ---
# pred_cluster_id: 414
# gold_cluster_id: 478
# extra: ['Copy Number Inference from Exome Reads', 'Genome Variation Server']
# missing: ['PBAP']
#
# --- merge_like ---
# pred_cluster_id: 415
# gold_cluster_id: 479
# extra: ['MERLIN']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 416
# gold_cluster_id: 480
# extra: []
# missing: ['Copy Number Inference from Exome Reads']
#
# --- merge_like ---
# pred_cluster_id: 418
# gold_cluster_id: 482
# extra: ['cnvHap', 'cnvHap', 'cnvHap']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 422
# gold_cluster_id: 340
# extra: []
# missing: ['CADD']
#
# --- split_like ---
# pred_cluster_id: 423
# gold_cluster_id: 478
# extra: []
# missing: ['Pedigree-Based Analysis Pipeline']
#
# --- split_like ---
# pred_cluster_id: 424
# gold_cluster_id: 489
# extra: []
# missing: ['SAMSCo', 'SAMSCo', 'SAMSCo']
#
# --- split_like ---
# pred_cluster_id: 425
# gold_cluster_id: 489
# extra: []
# missing: ['Statistical Analysis of Minimum cost path based Structural Connectivity']
#
# --- split_like ---
# pred_cluster_id: 426
# gold_cluster_id: 146
# extra: []
# missing: ['AFNI', 'AFNI', 'AFNI', 'AFNI', 'AFNI', 'AFNI', 'AFNI', 'AFNI', 'AFNI', 'AFNI', 'AFNI', 'AFNI', 'AFNI', 'AFNI', 'AFNI', 'AFNI', 'AFNI']
#
# --- merge_like ---
# pred_cluster_id: 427
# gold_cluster_id: 490
# extra: ['CloVR']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 445
# gold_cluster_id: 690
# extra: ['RNA-Skim', 'RNA-Skim', 'RNA-Skim']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 448
# gold_cluster_id: 703
# extra: ['OpenCV']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 451
# gold_cluster_id: 515
# extra: ['Scope-Pro']
# missing: ['IPP', 'IPP', 'IPP']
#
# --- split_like ---
# pred_cluster_id: 452
# gold_cluster_id: 515
# extra: []
# missing: ['Image-Pro Plus']
#
# --- merge_like ---
# pred_cluster_id: 462
# gold_cluster_id: 527
# extra: ['VBA']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 463
# gold_cluster_id: 528
# extra: []
# missing: ['OriginLab']
#
# --- merge_like ---
# pred_cluster_id: 464
# gold_cluster_id: 529
# extra: ['Pathomx', 'Pathomx', 'PathVisioRPC', 'Pathomx', 'Pathomx', 'Pathomx']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 468
# gold_cluster_id: 0
# extra: []
# missing: ['Matlab', 'MATLAB', 'Matlab', 'Matlab', 'MATLAB', 'MATLAB', 'Matlab', 'Matlab', 'Matlab', 'MATLAB', 'MATLAB', 'MATLAB', 'MATLAB', 'MATLAB', 'Matlab', 'MATLAB', 'MATLAB', 'MATLAB', 'Matlab', 'MATLAB', 'Matlab', 'Matlab', 'Matlab', 'MATLAB', 'MATLAB', 'Matlab', 'MATLAB', 'Matlab', 'Matlab', 'MATLAB', 'Matlab', 'MATLAB', 'MATLAB', 'MATLAB', 'MATLAB', 'MATLAB', 'MATLAB', 'MATLAB', 'Matlab', 'Matlab', 'Matlab', 'Matlab', 'Matlab', 'Matlab', 'Matlab', 'Matlab', 'MATLAB', 'MATLAB', 'Matlab', 'MATLAB', 'MATLAB', 'MATLAB', 'MATLAB', 'MATLAB', 'MATLAB', 'Matlab', 'Matlab', 'Matlab', 'MATLAB', 'MATLAB', 'Matlab', 'MATLAB', 'MATLAB', 'Matlab', 'MATLAB', 'Matlab', 'Matlab', 'MATLAB', 'Matlab', 'Matlab', 'MATLAB', 'MATLAB', 'Matlab', 'MATLAB', 'MATLAB', 'Matlab', 'MATLAB', 'Matlab', 'MATLAB', 'Matlab', 'MATLAB', 'MATLAB', 'MATLAB', 'Matlab', 'MATLAB', 'Matlab', 'Matlab', 'MATLAB', 'MATLAB', 'MatLab', 'MATLAB', 'Matlab', 'MATLAB', 'Matlab', 'Matlab', 'MATLAB', 'MATLAB', 'MATLAB', 'MATLAB', 'Matlab', 'MATLAB', 'MATLAB', 'MatLab', 'MATLAB', 'MATLAB', 'Matlab', 'Matlab', 'MATLAB', 'Matlab', 'Matlab', 'MATLAB', 'MATLAB', 'MATLAB', 'Matlab', 'Matlab', 'MATLAB', 'MATLAB', 'Matlab', 'Matlab', 'Matlab', 'MATLAB']
#
# --- merge_like ---
# pred_cluster_id: 474
# gold_cluster_id: 541
# extra: ['boot']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 475
# gold_cluster_id: 543
# extra: ['Debian']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 486
# gold_cluster_id: 555
# extra: []
# missing: ['MEDYAN', 'MEDYAN']
#
# --- split_like ---
# pred_cluster_id: 487
# gold_cluster_id: 555
# extra: []
# missing: ['Mechanochemical Dynamics of Active Networks']
#
# --- merge_like ---
# pred_cluster_id: 489
# gold_cluster_id: 557
# extra: ['MacVide', 'Actionscript']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 495
# gold_cluster_id: 568
# extra: ['H2O R interface']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 498
# gold_cluster_id: 575
# extra: ['tidyr']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 503
# gold_cluster_id: 582
# extra: ['caret']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 510
# gold_cluster_id: 593
# extra: ['Habit 2000']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 518
# gold_cluster_id: 451
# extra: []
# missing: ['DARTEL', 'DARTEL', 'DARTEL', 'DARTEL']
#
# --- merge_like ---
# pred_cluster_id: 526
# gold_cluster_id: 609
# extra: ['Ruby on Rails']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 527
# gold_cluster_id: 47
# extra: []
# missing: ['Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'windows', 'windows', 'Windows', 'Windows', 'Windows', 'windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Window', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'Windows', 'windows', 'Windows', 'Windows', 'Windows', 'Windows']
#
# --- merge_like ---
# pred_cluster_id: 538
# gold_cluster_id: 631
# extra: ['PyroTagger']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 555
# gold_cluster_id: 645
# extra: ['PLATON']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 562
# gold_cluster_id: 656
# extra: ['Biopython']
# missing: []
#
# --- merge_like ---
# pred_cluster_id: 569
# gold_cluster_id: 665
# extra: ['Nilearn']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 575
# gold_cluster_id: 2
# extra: []
# missing: ['SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'Statistical Package for Social Science', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'Statistical Program for the Social Sciences', 'SPSS', 'Statistical Package for Social Sciences', 'Statistical Package for the Social Science', 'SPSS', 'SPSS', 'SPSS', 'Software Package for Statistical Analysis', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Dimensions', 'Statistical Package for Social Sciences', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'Statistical Package for Social Sciences', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS Statistics', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS Statistics', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'PASW Statistics', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS Statistics', 'SPSS', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS Statistics', 'SPSS Statistics', 'PASW Statistics', 'SPSS', 'SPSS Statistics', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS Statistics', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'Statistical Package for the Social Science', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS statistics', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'PASW', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'Statistical Package for the Social Sciences', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS statistics', 'SPSS', 'SPSS', 'SPSS', 'PASW Statistic', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'PASW Statistic', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'Statistical Package for Social Sciences', 'Statistical Package for Social Sciences', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'SPSS statistics', 'Statistical package for Social Sciences', 'SPSS Statistics', 'SPSS', 'SPSS', 'SPSS', 'statistical package for social sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'Statistical Package for Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS', 'SPSS Statistics', 'SPSS Statistics', 'SPSS', 'SPSS', 'Statistical Package for the Social Sciences', 'SPSS', 'SPSS', 'SPSS', 'SPS ...
#
# --- merge_like ---
# pred_cluster_id: 577
# gold_cluster_id: 676
# extra: ['OriginLab']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 588
# gold_cluster_id: 195
# extra: []
# missing: ['SPSS Amos', 'AMOS', 'AMOS', 'SPSS AMOS', 'AMOS', 'AMOS']
#
# --- merge_like ---
# pred_cluster_id: 593
# gold_cluster_id: 695
# extra: ['OntoFox']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 598
# gold_cluster_id: 701
# extra: []
# missing: ['Relationship Estimation from Ancient DNA']
#
# --- split_like ---
# pred_cluster_id: 599
# gold_cluster_id: 701
# extra: []
# missing: ['READ', 'READ', 'READ', 'READ', 'READ', 'READ', 'READ', 'READ']
#
# --- split_like ---
# pred_cluster_id: 600
# gold_cluster_id: 19
# extra: []
# missing: ['R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R']
#
# --- merge_like ---
# pred_cluster_id: 604
# gold_cluster_id: 706
# extra: ['COBRApy']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 606
# gold_cluster_id: 709
# extra: []
# missing: ['CCS', 'CCS', 'CCS']
#
# --- split_like ---
# pred_cluster_id: 607
# gold_cluster_id: 709
# extra: []
# missing: ['Clinical Classifications Software']
#
# --- merge_like ---
# pred_cluster_id: 610
# gold_cluster_id: 713
# extra: ['Mechanical Turk']
# missing: []
#
# --- split_like ---
# pred_cluster_id: 618
# gold_cluster_id: 521
# extra: []
# missing: ['ENSEMBLE']

# %%
fuzzy_error_type_count = {key:0 for key in ["split_like", "merge_like", "mismatch"]}
embedding_error_type_count = {key:0 for key in ["split_like", "merge_like", "mismatch"]}

# %%
for ex in fuzzy_mismatch_examples:
    error_type = ex["type"]
    fuzzy_error_type_count[error_type] += 1

for ex in embedding_mismatch_examples:
    error_type = ex["type"]
    embedding_error_type_count[error_type] += 1

# %%
print(fuzzy_error_type_count)
print(embedding_error_type_count)
# Out:
# {'split_like': 129, 'merge_like': 28, 'mismatch': 0}
# {'split_like': 63, 'merge_like': 105, 'mismatch': 0}
